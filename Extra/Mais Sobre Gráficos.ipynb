# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
plt.rc("figure", figsize=(15,8))

dados = pd.read_csv("../dados/aluguel_residencial_sem_outliers.csv", sep=";")
dados.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0         Tipo               Bairro  Quartos  Vagas  \
# 0             2           2  Apartamento               Centro        1      0
# 1             3           3  Apartamento         Higienópolis        1      0
# 2             4           5  Apartamento             Cachambi        2      0
# 3             7           9  Apartamento               Grajaú        2      1
# 4             8          10  Apartamento  Lins de Vasconcelos        3      1
#
#    Suites  Area   Valor  Condominio  IPTU  Valor m2 Tipo agregado
# 0       0    15   800.0       390.0  20.0     53.33   Apartamento
# 1       0    48   800.0       230.0   0.0     16.67   Apartamento
# 2       0    50  1300.0       301.0  17.0     26.00   Apartamento
# 3       0    70  1500.0       642.0  74.0     21.43   Apartamento
# 4       1    90  1500.0       455.0  14.0     16.67   Apartamento

# %%
area = plt.figure()

# %%
g1 = area.add_subplot(2,2,1)
g2 = area.add_subplot(2,2,2)
g3 = area.add_subplot(2,2,3)
g4 = area.add_subplot(2,2,4)

# %%
g1.set_label("Valor X Área")
g1.scatter(dados.Valor, dados.Area)

g2.set_title("Histograma")
g2.hist(dados.Valor)

g3.set_title("Amostra (valor)")
dados_g3 = dados["Valor"].sample(100)
dados_g3.index = range(100)
g3.plot(dados_g3)

g4.set_title("Valor médio por tipo")
grupo = dados.groupby("Tipo")["Valor"]
g4.bar(grupo.mean().index, grupo.mean().values)

area

# %%
area.savefig("grafico.png", dpi=300)
